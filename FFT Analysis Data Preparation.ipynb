# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("p_wave/Before/25/B25_1.csv")

# %%
time = np.arange(0,1000,0.5)
len(time)
# Out:
# 2000

# %%
y_val = [0]*2000
for i in range(2000):
    y_val[i]=df.iloc[18][i]

# %%
plt.figure(figsize=(16,4))
plt.plot(time, df.iloc[18].astype(float))
